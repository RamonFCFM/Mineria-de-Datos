# %% [markdown]
# ## prototipo red neuronal

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import pandas_profiling 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
datos=pd.read_csv("vjuegos.csv")
from sklearn.preprocessing import LabelEncoder
datos
# Out:
#                                             Name Platform  Year_of_Release  \
# 0                                Rapala Trophies      PSP             2006
# 1                        New Super Mario Bros. U     WiiU             2012
# 2                                         Robots      PS2             2005
# 3                                 Hamster Club 3      GBA             2002
# 4                                   Formula 1 06      PS2             2006
# ...                                          ...      ...              ...
# 11694                    Call of Duty: Black Ops     X360             2010
# 11695                               Resistance 3      PS3             2011
# 11696                  Ready 2 Rumble Revolution      Wii             2009
# 11697  Monster Hunter Frontier Online: Forward 2     X360             2011
# 11698                                    NHL 2K9      PS3             2008
#
#               Genre                    Publisher  NA_Sales  EU_Sales  \
# 0            Sports                   Activision     40000         0
# 1          Platform                     Nintendo   2300000   1340000
# 2            Action                Vivendi Games    180000    140000
# 3        Simulation                      Jorudan         0         0
# 4            Racing  Sony Computer Entertainment         0         0
# ...             ...                          ...       ...       ...
# 11694       Shooter                   Activision   9700000   3680000
# 11695       Shooter  Sony Computer Entertainment    640000    570000
# 11696        Sports                        Atari    150000         0
# 11697  Role-Playing                       Capcom         0         0
# 11698        Sports         Take-Two Interactive    110000     10000
#
#        JP_Sales  Critic_Score
# 0             0            47
# 1       1270000            82
# 2             0            93
# 3        350000            66
# 4         40000            71
# ...         ...           ...
# 11694    110000            95
# 11695     50000            49
# 11696         0            95
# 11697     30000            75
# 11698         0            51
#
# [11699 rows x 9 columns]

# %%
#from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
enconder=LabelEncoder()
datos['Generos']=enconder.fit_transform(datos.Genre.values)
datos['Plataformas']=enconder.fit_transform(datos.Platform.values)
datos['Empresa']=enconder.fit_transform(datos.Publisher.values)
datos['Titulos']=enconder.fit_transform(datos.Name.values)

datos
# Out:
#                                             Name Platform  Year_of_Release  \
# 0                                Rapala Trophies      PSP             2006
# 1                        New Super Mario Bros. U     WiiU             2012
# 2                                         Robots      PS2             2005
# 3                                 Hamster Club 3      GBA             2002
# 4                                   Formula 1 06      PS2             2006
# ...                                          ...      ...              ...
# 11694                    Call of Duty: Black Ops     X360             2010
# 11695                               Resistance 3      PS3             2011
# 11696                  Ready 2 Rumble Revolution      Wii             2009
# 11697  Monster Hunter Frontier Online: Forward 2     X360             2011
# 11698                                    NHL 2K9      PS3             2008
#
#               Genre                    Publisher  NA_Sales  EU_Sales  \
# 0            Sports                   Activision     40000         0
# 1          Platform                     Nintendo   2300000   1340000
# 2            Action                Vivendi Games    180000    140000
# 3        Simulation                      Jorudan         0         0
# 4            Racing  Sony Computer Entertainment         0         0
# ...             ...                          ...       ...       ...
# 11694       Shooter                   Activision   9700000   3680000
# 11695       Shooter  Sony Computer Entertainment    640000    570000
# 11696        Sports                        Atari    150000         0
# 11697  Role-Playing                       Capcom         0         0
# 11698        Sports         Take-Two Interactive    110000     10000
#
#        JP_Sales  Critic_Score  Generos  Plataformas  Empresa  Titulos
# 0             0            47       10           18       21     5892
# 1       1270000            82        4           26      329     5160
# 2             0            93        0           15      492     6107
# 3        350000            66        9            6      241     2965
# 4         40000            71        6           15      414     2490
# ...         ...           ...      ...          ...      ...      ...
# 11694    110000            95        8           27       21      946
# 11695     50000            49        8           16      414     6026
# 11696         0            95       10           25       51     5946
# 11697     30000            75        7           27       82     4626
# 11698         0            51       10           16      448     5006
#
# [11699 rows x 13 columns]

# %%
from sklearn import linear_model
from sklearn.metrics import r2_score
regr = linear_model.LinearRegression()
#pred=dict(zip(datos.Generos.unique(),datos.Genre.unique()))
#y=pred
y=datos['Generos']
x=datos['Empresa']
X=x[:,np.newaxis]
print(X)
print(regr.fit(X,y))
print(regr.coef_)
m=regr.coef_[0]
b=regr.intercept_
y_pred =m*X+b
print('y={0}*x+{1}'.format(m,b))
print(regr.predict(X)[0:20])
print("El valor de r^2 :",r2_score(y,y_pred))
plt.scatter(x,y, color='blue')
plt.plot(X,y_pred,color='red')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-122-a4567e25222c> in <module>
#       4 #pred=dict(zip(datos.Generos.unique(),datos.Genre.unique()))
#       5 #y=pred
# ----> 6 y=datos['Generos'.unique()]
#       7 x=datos['Empresa']
#       8 X=x[:,np.newaxis]
#
# AttributeError: 'str' object has no attribute 'unique'

# %%
X=datos[['Plataformas','Empresa','NA_Sales']]
y=datos['Genre']

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y)

from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
scaler.fit(X_train)
X_train= scaler.transform(X_train)
X_test= scaler.transform(X_test)


from sklearn.neural_network import MLPClassifier
mlp= MLPClassifier(hidden_layer_sizes=(10,10,10),max_iter=5000,alpha=0.0001,solver='adam',random_state=21,tol=1e-10)
#mlp=MLPClassifier(hidden_layer_sizes(5,5,5,5),max_iter=5000)

mlp.fit(X_train,y_train)
predictions=mlp.predict(X_test,X_train)

from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-cb1a78505672> in <module>
#      17
#      18 mlp.fit(X_train,y_train)
# ---> 19 predictions=mlp.predict(X_test,X_train)
#      20
#      21 from sklearn.metrics import classification_report
#
# TypeError: predict() takes 2 positional arguments but 3 were given

# %%
from sklearn.neural_network import MLPRegressor

y=datos['Generos']
x=datos['Year_of_Release']

X=x[:,np.newaxis]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y)

mlr=MLPRegressor(solver='lbfgs',alpha=0.001,hidden_layer_sizes=(10,10),random_state=1)
mlr.fit(X_train,y_train)
print(mlr.score(X_train,y_train))
print("prediccion en 2006 ",mlr.predict(2010))
# Out:
# -0.0008803838898554517
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-3bcccfb949b9> in <module>
#      11 mlr.fit(X_train,y_train)
#      12 print(mlr.score(X_train,y_train))
# ---> 13 print("prediccion en 2006 ",mlr.predict(2010))
#
# ~\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py in predict(self, X)
#    1310         """
#    1311         check_is_fitted(self, "coefs_")
# -> 1312         y_pred = self._predict(X)
#    1313         if y_pred.shape[1] == 1:
#    1314             return y_pred.ravel()
#
# ~\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py in _predict(self, X)
#     660             The decision function of the samples for each class in the model.
#     661         """
# --> 662         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     663
#     664         # Make sure self.hidden_layer_sizes is a list
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     512                     "Reshape your data either using array.reshape(-1, 1) if "
#     513                     "your data has a single feature or array.reshape(1, -1) "
# --> 514                     "if it contains a single sample.".format(array))
#     515             # If input is 1D raise error
#     516             if array.ndim == 1:
#
# ValueError: Expected 2D array, got scalar array instead:
# array=2010.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
from sklearn.model_selection import train_test_split

pred=dict(zip(datos.Generos.unique(),datos.Genre.unique()))
print("hola",pred)


#predd=dict(zip(datos.Titulos.unique(),datos.Name.unique()))
#print(predd)

X=datos[['NA_Sales','EU_Sales']]
y=datos['Generos']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.5,random_state=42)
#print(X_train.describe())

from sklearn.neighbors import KNeighborsClassifier
neighbors=np.arange(1,9)
train_exactitud=np.empty(len(neighbors))
test_exactitud=np.empty(len(neighbors))

for i,k in enumerate(neighbors):
    knn= KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    train_exactitud[i]=knn.score(X_train,y_train)
    test_exactitud[i]=knn.score(X_test,y_test)

plt.title("Variacion vecinos en knn")
plt.plot(neighbors,test_exactitud,label="Test_Exactitud")
plt.plot(neighbors,train_exactitud,label="Train_Exactitud")
plt.legend()
plt.xlabel("Vecinos")
plt.ylabel("Exactitud")
plt.show()


knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
print(knn.score(X_test,y_test))
pred1=knn.predict([['180000','140000']])
print(pred[pred1[0]])

print("RandomForest")
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(X_train,y_train)
print(rfc.score(X_test,y_test))
pred2=rfc.predict([['180000','140000']])
print(pred[pred2[0]])
# Out:
# hola {10: 'Sports', 4: 'Platform', 0: 'Action', 9: 'Simulation', 6: 'Racing', 7: 'Role-Playing', 8: 'Shooter', 2: 'Fighting', 3: 'Misc', 11: 'Strategy', 1: 'Adventure', 5: 'Puzzle'}
# 0.165982905982906
# Sports
# RandomForest
# 0.1688888888888889
# Sports
# C:\Users\Franc\Anaconda3\lib\site-packages\sklearn\utils\validation.py:532: FutureWarning: Beginning in version 0.22, arrays of bytes/strings will be converted to decimal numbers if dtype='numeric'. It is recommended that you convert the array to a float dtype before using it in scikit-learn, for example by using your_array = your_array.astype(np.float64).
#   FutureWarning)
# C:\Users\Franc\Anaconda3\lib\site-packages\sklearn\utils\validation.py:532: FutureWarning: Beginning in version 0.22, arrays of bytes/strings will be converted to decimal numbers if dtype='numeric'. It is recommended that you convert the array to a float dtype before using it in scikit-learn, for example by using your_array = your_array.astype(np.float64).
#   FutureWarning)
# C:\Users\Franc\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
from sklearn.model_selection import train_test_split

pred=dict(zip(datos.Generos.unique(),datos.Genre.unique()))
print("hola",pred)


#pred=dict(zip(datos.Titulos.unique(),datos.Name.unique()))
#print(pred)

X=datos[['Titulos','Empresa']]
y=datos['Generos']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.5,random_state=42)
#print(X_train.describe())

from sklearn.neighbors import KNeighborsClassifier
neighbors=np.arange(1,9)
train_exactitud=np.empty(len(neighbors))
test_exactitud=np.empty(len(neighbors))

for i,k in enumerate(neighbors):
    knn= KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    train_exactitud[i]=knn.score(X_train,y_train)
    test_exactitud[i]=knn.score(X_test,y_test)

plt.title("Variacion vecinos en knn")
plt.plot(neighbors,test_exactitud,label="Test_Exactitud")
plt.plot(neighbors,train_exactitud,label="Train_Exactitud")
plt.legend()
plt.xlabel("Vecinos")
plt.ylabel("Exactitud")
plt.show()


knn=KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train,y_train)
print(knn.score(X_test,y_test))
pred1=knn.predict([['946','24']])
print(pred[pred1[0]])

print("RandomForest")
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(X_train,y_train)
print(rfc.score(X_test,y_test))
pred2=rfc.predict([['946','24']])
print(pred[pred2[0]])
# Out:
# hola {10: 'Sports', 4: 'Platform', 0: 'Action', 9: 'Simulation', 6: 'Racing', 7: 'Role-Playing', 8: 'Shooter', 2: 'Fighting', 3: 'Misc', 11: 'Strategy', 1: 'Adventure', 5: 'Puzzle'}
# 0.5673504273504274
# Shooter
# RandomForest
# C:\Users\Franc\Anaconda3\lib\site-packages\sklearn\utils\validation.py:532: FutureWarning: Beginning in version 0.22, arrays of bytes/strings will be converted to decimal numbers if dtype='numeric'. It is recommended that you convert the array to a float dtype before using it in scikit-learn, for example by using your_array = your_array.astype(np.float64).
#   FutureWarning)
# C:\Users\Franc\Anaconda3\lib\site-packages\sklearn\utils\validation.py:532: FutureWarning: Beginning in version 0.22, arrays of bytes/strings will be converted to decimal numbers if dtype='numeric'. It is recommended that you convert the array to a float dtype before using it in scikit-learn, for example by using your_array = your_array.astype(np.float64).
#   FutureWarning)
# C:\Users\Franc\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.5622222222222222
# Shooter
