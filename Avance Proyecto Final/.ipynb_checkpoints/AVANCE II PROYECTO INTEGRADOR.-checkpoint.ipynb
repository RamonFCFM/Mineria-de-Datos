# %% [markdown]
# # Avance II Proyecto Final
# ### Equipo #3
# ### Grupo: 006
# ### Frecuencia : Lunes, Miercoles,Viernes  6-7 pm
# ### Integrantes :
# * Francisco Ramon Ramirez Torres 1739900.
# * Cesar Gerardo Varela Cavazos 1748727.
# * Cesar Alejandro Barrera Martinez 1618509

# %% [markdown]
# ## Titulo: Video Games Sales. (Información histórica de ventas de videojuegos)

# %% [markdown]
# ## Descripcion de la Base de Datos:
#
#  Esta base de datos contiene toda la historia de los videojuegos lanzados en su respectivo, año fundada en una empresa en particular, con su respectiva plataforma y las ventas que ha tenido en el Norte de America, EE.UU, Japon, etc; al igual que las ventas globales que ha tenido.

# %% [markdown]
# ## Descripcion de las columnas:
# * Contiene nombre, genero, año de publicacion, plataforma, empresa desarrolladora, ventas en Estados Unidos,Norteamerica, Japon y categoria.
# * Los tipos de datos que contiene la base de datos son String, flotantes, Caracter, contando con aproximadamente 10 mil registros de los videojuegos.

# %% [markdown]
# ## Justificacion del uso de los datos.
# * a). Cuáles fueron las características que les llamó la atención de los datos. Qué les hizo querer trabajar con ellos.
#     La diversa información acerca de los videojuegos, como la distribución de venta, popularidad de videojuegos, diversa variedad con géneros en los títulos de videojuegos y competencia entre empresas que tienen juegos similares en popularidad.
#
# * b) Qué beneficio encuentran de trabajar con estos datos.
#   Poder encontrar algún beneficio de manera que podemos calcular un precio estimado de un videojuego, ver un análisis de ventas sobre cómo se han visto ventas con otras empresas, podemos ver qué clase de videojuegos se han vendido más a través de los años según su aceptación para las empresas que se dedican a crear juegos puedan saber que genero es el que deben crear más.

# %% [markdown]
# ## Preguntas de Interes
# ¿Cuál es la percepción de aceptación de videojuegos de las empresas ?
#
# ¿Con los datos de la base de datos de videojuegos como se pueden clasificar aplicando algún método de minería de datos?
#
# ¿Cómo se puede aplicar una red neuronal con de tipo clasificación con la base de datos?

# %% [markdown]
# ### 1. Limpieza de datos

# %%
import numpy as np
import pandas as pd
import json
import seaborn as sn
import pandas_profiling 
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# C:\Users\Franc\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# * importacion de librerias

# %%
games = pd.read_csv("train.csv")

# %% [markdown]
# * Con esta variable games la usaremos para abrir nuestra BD de los videojuegos

# %% [markdown]
# ###### a)	Mostrar los datos sin manipulación

# %%
games.head()
# Out:
#                       Name Platform  Year_of_Release       Genre  \
# 0          Rapala Trophies      PSP           2006.0      Sports
# 1  New Super Mario Bros. U     WiiU           2012.0    Platform
# 2                   Robots      PS2           2005.0      Action
# 3           Hamster Club 3      GBA           2002.0  Simulation
# 4             Formula 1 06      PS2           2006.0      Racing
#
#                      Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                   Activision      0.04      0.00      0.00         0.00
# 1                     Nintendo      2.30      1.34      1.27         0.32
# 2                Vivendi Games      0.18      0.14      0.00         0.05
# 3                      Jorudan      0.00      0.00      0.35         0.01
# 4  Sony Computer Entertainment      0.00      0.00      0.04         0.00
#
#    Critic_Score  Critic_Count  User_Score  User_Count  \
# 0           NaN           NaN         NaN         NaN
# 1          84.0          70.0         8.1       733.0
# 2          53.0           6.0         6.0         8.0
# 3           NaN           NaN         NaN         NaN
# 4           NaN           NaN         NaN         NaN
#
#                         Developer Rating
# 0              Sand Grain Studios      E
# 1                        Nintendo      E
# 2  Eurocom Entertainment Software      E
# 3                             NaN    NaN
# 4                             NaN    NaN

# %% [markdown]
# * Usamos la funcion head() para mostrar los primeros 5 registros solo para revisar si cargo correctamente

# %%
games.tail()
# Out:
#                                             Name Platform  Year_of_Release  \
# 11698                    Call of Duty: Black Ops     X360           2010.0
# 11699                               Resistance 3      PS3           2011.0
# 11700                  Ready 2 Rumble Revolution      Wii           2009.0
# 11701  Monster Hunter Frontier Online: Forward 2     X360           2011.0
# 11702                                    NHL 2K9      PS3           2008.0
#
#               Genre                    Publisher  NA_Sales  EU_Sales  \
# 11698       Shooter                   Activision      9.70      3.68
# 11699       Shooter  Sony Computer Entertainment      0.64      0.57
# 11700        Sports                        Atari      0.15      0.00
# 11701  Role-Playing                       Capcom      0.00      0.00
# 11702        Sports         Take-Two Interactive      0.11      0.01
#
#        JP_Sales  Other_Sales  Critic_Score  Critic_Count  User_Score  \
# 11698      0.11         1.13          87.0          89.0         6.3
# 11699      0.05         0.22          83.0          91.0         7.8
# 11700      0.00         0.01          37.0          31.0         NaN
# 11701      0.03         0.00           NaN           NaN         NaN
# 11702      0.00         0.01          70.0          21.0         NaN
#
#        User_Count        Developer Rating
# 11698      1454.0         Treyarch      M
# 11699       543.0  Insomniac Games      M
# 11700         NaN  10tacle Studios      T
# 11701         NaN              NaN    NaN
# 11702         NaN  Visual Concepts   E10+

# %% [markdown]
# * Usamos la funcion tail() para mostrar los primeros 5 registros solo para revisar si cargo correctamente
# * Como se ve con la fucion head() y tail() se muestran registros con alguno de los registros de videojuegos contando con nombres, ventas, puntuaciones, genero

# %%
games.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %% [markdown]
# ###### b)	Eliminar columnas no deseadas.

# %%
games2 = games.drop_duplicates(['Name','Platform','Publisher'])

# %%
nuevaBD = games2.drop(['User_Count', 'User_Score', 'Critic_Count','Critic_Score','Developer','Other_Sales'], axis=1)

# %%
nuevaBD
# Out:
#                                             Name Platform  Year_of_Release  \
# 0                                Rapala Trophies      PSP           2006.0
# 1                        New Super Mario Bros. U     WiiU           2012.0
# 2                                         Robots      PS2           2005.0
# 3                                 Hamster Club 3      GBA           2002.0
# 4                                   Formula 1 06      PS2           2006.0
# ...                                          ...      ...              ...
# 11698                    Call of Duty: Black Ops     X360           2010.0
# 11699                               Resistance 3      PS3           2011.0
# 11700                  Ready 2 Rumble Revolution      Wii           2009.0
# 11701  Monster Hunter Frontier Online: Forward 2     X360           2011.0
# 11702                                    NHL 2K9      PS3           2008.0
#
#               Genre                    Publisher  NA_Sales  EU_Sales  \
# 0            Sports                   Activision      0.04      0.00
# 1          Platform                     Nintendo      2.30      1.34
# 2            Action                Vivendi Games      0.18      0.14
# 3        Simulation                      Jorudan      0.00      0.00
# 4            Racing  Sony Computer Entertainment      0.00      0.00
# ...             ...                          ...       ...       ...
# 11698       Shooter                   Activision      9.70      3.68
# 11699       Shooter  Sony Computer Entertainment      0.64      0.57
# 11700        Sports                        Atari      0.15      0.00
# 11701  Role-Playing                       Capcom      0.00      0.00
# 11702        Sports         Take-Two Interactive      0.11      0.01
#
#        JP_Sales Rating
# 0          0.00      E
# 1          1.27      E
# 2          0.00      E
# 3          0.35    NaN
# 4          0.04    NaN
# ...         ...    ...
# 11698      0.11      M
# 11699      0.05      M
# 11700      0.00      T
# 11701      0.03    NaN
# 11702      0.00   E10+
#
# [11700 rows x 9 columns]

# %% [markdown]
# * Eliminamos algunas columnas que no nos ayudan tanto ya que muchos datos eran vacios o NaN y no nos serviria hacer analisis de datos vacios. Esto nos complicaria mas hacer analisis y agregar valores para los datos de columnas faltantes lo que es mejor eliminarlas para evitar problemas y no utilizar valores falsos o inventados y puedan afectar estadisticas.

# %% [markdown]
# ###### c)	Correcta manipulación de los datos nulos dentro de la base de datos.

# %%
nuevaBD = nuevaBD.fillna('E')

# %%
nuevaBD
# Out:
#                                             Name Platform Year_of_Release  \
# 0                                Rapala Trophies      PSP            2006
# 1                        New Super Mario Bros. U     WiiU            2012
# 2                                         Robots      PS2            2005
# 3                                 Hamster Club 3      GBA            2002
# 4                                   Formula 1 06      PS2            2006
# ...                                          ...      ...             ...
# 11698                    Call of Duty: Black Ops     X360            2010
# 11699                               Resistance 3      PS3            2011
# 11700                  Ready 2 Rumble Revolution      Wii            2009
# 11701  Monster Hunter Frontier Online: Forward 2     X360            2011
# 11702                                    NHL 2K9      PS3            2008
#
#               Genre                    Publisher  NA_Sales  EU_Sales  \
# 0            Sports                   Activision      0.04      0.00
# 1          Platform                     Nintendo      2.30      1.34
# 2            Action                Vivendi Games      0.18      0.14
# 3        Simulation                      Jorudan      0.00      0.00
# 4            Racing  Sony Computer Entertainment      0.00      0.00
# ...             ...                          ...       ...       ...
# 11698       Shooter                   Activision      9.70      3.68
# 11699       Shooter  Sony Computer Entertainment      0.64      0.57
# 11700        Sports                        Atari      0.15      0.00
# 11701  Role-Playing                       Capcom      0.00      0.00
# 11702        Sports         Take-Two Interactive      0.11      0.01
#
#        JP_Sales Rating
# 0          0.00      E
# 1          1.27      E
# 2          0.00      E
# 3          0.35      E
# 4          0.04      E
# ...         ...    ...
# 11698      0.11      M
# 11699      0.05      M
# 11700      0.00      T
# 11701      0.03      E
# 11702      0.00   E10+
#
# [11703 rows x 9 columns]

# %%
Videojuegos = nuevaBD

Videojuegos.to_csv('Videojuegos.csv', index=False)

# %%
games2 = pd.read_csv("Videojuegos.csv")

# %%
games2
# Out:
#                                                Name Platform Year_of_Release  \
# 0                                   Rapala Trophies      PSP          2006.0
# 1                           New Super Mario Bros. U     WiiU          2012.0
# 2                                            Robots      PS2          2005.0
# 3                                    Hamster Club 3      GBA          2002.0
# 4                                      Formula 1 06      PS2          2006.0
# ...                                             ...      ...             ...
# 8776                                    Chessmaster      PS2          2003.0
# 8777  Itoi Shigesato no Bass Tsuri No. 1 Ketteihan!      N64          2000.0
# 8778                                   Resistance 3      PS3          2011.0
# 8779                      Ready 2 Rumble Revolution      Wii          2009.0
# 8780      Monster Hunter Frontier Online: Forward 2     X360          2011.0
#
#              Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0           Sports                   Activision      0.04      0.00      0.00
# 1         Platform                     Nintendo      2.30      1.34      1.27
# 2           Action                Vivendi Games      0.18      0.14      0.00
# 3       Simulation                      Jorudan      0.00      0.00      0.35
# 4           Racing  Sony Computer Entertainment      0.00      0.00      0.04
# ...            ...                          ...       ...       ...       ...
# 8776          Misc                      Ubisoft      0.19      0.15      0.00
# 8777        Sports                     Nintendo      0.00      0.00      0.07
# 8778       Shooter  Sony Computer Entertainment      0.64      0.57      0.05
# 8779        Sports                        Atari      0.15      0.00      0.00
# 8780  Role-Playing                       Capcom      0.00      0.00      0.03
#
#      Rating
# 0         E
# 1         E
# 2         E
# 3         E
# 4         E
# ...     ...
# 8776      E
# 8777      E
# 8778      M
# 8779      T
# 8780      E
#
# [8781 rows x 9 columns]

# %%
Mostramos la nueva Base de Datos con columnas y datos que no servirian, asi que se puede crear una mejor visualizacion de datos sin tener errores ni nombres repetidos de videjuegos

# %%
Capcom = games2[games2['Publisher']=='Capcom']

# %%
Capcom_acccion = games2[games2['Genre']=='Action']

# %%
Deportes
# Out:
#                                                Name Platform Year_of_Release  \
# 0                                   Rapala Trophies      PSP          2006.0
# 8                                   Madden NFL 2003       XB          2002.0
# 11                           Pro Yaky? Spirits 2012      PSV          2012.0
# 18                              ESPN NBA Basketball      PS2          2003.0
# 22                               Virtua Tennis 2009     X360          2009.0
# ...                                             ...      ...             ...
# 8757                     J-League '96 Dream Stadium     SNES          1996.0
# 8765                           NCAA Final Four 2001       PS          2000.0
# 8770                         World Tour Soccer 2005      PS2          2004.0
# 8777  Itoi Shigesato no Bass Tsuri No. 1 Ketteihan!      N64          2000.0
# 8779                      Ready 2 Rumble Revolution      Wii          2009.0
#
#        Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0     Sports                    Activision      0.04      0.00      0.00
# 8     Sports               Electronic Arts      0.67      0.02      0.00
# 11    Sports  Konami Digital Entertainment      0.00      0.00      0.06
# 18    Sports                          Sega      0.26      0.21      0.00
# 22    Sports                          Sega      0.12      0.18      0.00
# ...      ...                           ...       ...       ...       ...
# 8757  Sports                   Hudson Soft      0.00      0.00      0.05
# 8765  Sports   Sony Computer Entertainment      0.09      0.06      0.00
# 8770  Sports   Sony Computer Entertainment      0.08      0.06      0.00
# 8777  Sports                      Nintendo      0.00      0.00      0.07
# 8779  Sports                         Atari      0.15      0.00      0.00
#
#      Rating
# 0         E
# 8         E
# 11        E
# 18        E
# 22        E
# ...     ...
# 8757      E
# 8765      E
# 8770      E
# 8777      E
# 8779      T
#
# [1093 rows x 9 columns]

# %%
Deportes['Platform'].value_counts().plot.bar()

# %%
Capcom
# Out:
#                                                 Name Platform Year_of_Release  \
# 54                             DuckTales: Remastered       PC          2013.0
# 57                      Resident Evil Director's Cut      PS3          2006.0
# 166                    Dead Rising 2: Off the Record       PC          2011.0
# 190                                        Bombastic      PS2          2002.0
# 269                          Mega Man Battle Network      GBA          2001.0
# ...                                              ...      ...             ...
# 8706                               Ghosts 'n Goblins      NES          1986.0
# 8713                               Mega Man Xtreme 2       GB          2001.0
# 8725                Sengoku Basara: Chronicle Heroes      PSP          2011.0
# 8751  Phoenix Wright: Ace Attorney - Justice for All       DS          2006.0
# 8780       Monster Hunter Frontier Online: Forward 2     X360          2011.0
#
#              Genre Publisher  NA_Sales  EU_Sales  JP_Sales Rating
# 54          Action    Capcom      0.00      0.01      0.00      E
# 57          Action    Capcom      0.00      0.00      0.05      E
# 166         Action    Capcom      0.04      0.02      0.00      M
# 190         Puzzle    Capcom      0.03      0.02      0.00      E
# 269   Role-Playing    Capcom      0.14      0.05      0.22      E
# ...            ...       ...       ...       ...       ...    ...
# 8706        Action    Capcom      0.74      0.26      0.61      E
# 8713      Platform    Capcom      0.00      0.00      0.07      E
# 8725        Action    Capcom      0.00      0.00      0.16      E
# 8751     Adventure    Capcom      0.21      0.04      0.26      E
# 8780  Role-Playing    Capcom      0.00      0.00      0.03      E
#
# [219 rows x 9 columns]

# %%
Capcom[Capcom['Platform'] < 100].plot.hexbin(x='Platform', y='NA_Sales', gridsize=15)

# %%
Capcom_accion
